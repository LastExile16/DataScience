# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ### Data Genration

# %%
observations = 1000

# generated_inputs = np.random.uniform(low=-10, high=10, size=(observations, 2))
xs = np.random.uniform(low=-10, high=10, size=(observations, 1))
zs = np.random.uniform(-10, 10, (observations, 1))
generated_inputs = np.column_stack((xs, zs))

noise = np.random.uniform(-1,1, (observations, 1))

generated_targets = 2*xs - 3*zs + noise

np.savez('TF_intro', inputs=generated_inputs, targets=generated_targets)

# %% [markdown]
# ### Solving with TensorFlow

# %%
training_data = np.load('TF_intro.npz' )
training_data['inputs'].shape
training_data['targets'].shape
# Out:
# (1000, 1)

# %% [markdown]
# #### build the model
# * Data: we have generated some fake data.
# * Model: our model we want to build is linear.
# * Objective function (loss function):
#     * we want it L2_norm
#     * L2_norm is scaled SSE
#     * scalled SSE is the same as MSE (mean squared error)
# * Optimization algorithm: we want gradient descent. in TF we can stochastic gradient descent SGD

# %% [markdown]
# ##### guidelines for determining the batch size:
# * For small datasets, use a small batch size, such as 16 or 32.
# * For large datasets, use a larger batch size, such as 128 or 256.
# * If the model is overfitting, try using a smaller batch size.
# * If the model is not converging, try using a larger batch size.
# * Experiment with different batch sizes to find the best performance on a held-out validation set.

# %%
# in numpy code: output = np.dot(inputs, weight) + noise
# tf.keras.layers.Dense() takes the input provided to the model and calculates the dot product of the inputs and the weights and adds the bias
input_size = 2
output_size = 1

model = tf.keras.Sequential([
                            tf.keras.layers.Dense(
                                output_size,
                                kernel_initializer = tf.random_uniform_initializer(minval=-0.1, maxval=0.1),
                                bias_initializer = tf.random_uniform_initializer(minval=-0.1, maxval=0.1)
                                )
                            ])
# custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
custom_optimizer = tf.keras.optimizers.Adam()
# model.compile(optimizer=custom_optimizer, loss='mean_squared_error')
model.compile(optimizer=custom_optimizer, loss='huber_loss')
model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=2, batch_size=10)
#
# Out:
# Epoch 1/100
# 100/100 - 0s - loss: 15.7387 - 322ms/epoch - 3ms/step
# Epoch 2/100
# 100/100 - 0s - loss: 15.1773 - 117ms/epoch - 1ms/step
# Epoch 3/100
# 100/100 - 0s - loss: 14.6131 - 134ms/epoch - 1ms/step
# Epoch 4/100
# 100/100 - 0s - loss: 14.0518 - 153ms/epoch - 2ms/step
# Epoch 5/100
# 100/100 - 0s - loss: 13.4917 - 150ms/epoch - 2ms/step
# Epoch 6/100
# 100/100 - 0s - loss: 12.9333 - 148ms/epoch - 1ms/step
# Epoch 7/100
# 100/100 - 0s - loss: 12.3740 - 152ms/epoch - 2ms/step
# Epoch 8/100
# 100/100 - 0s - loss: 11.8177 - 147ms/epoch - 1ms/step
# Epoch 9/100
# 100/100 - 0s - loss: 11.2630 - 146ms/epoch - 1ms/step
# Epoch 10/100
# 100/100 - 0s - loss: 10.7071 - 150ms/epoch - 1ms/step
# Epoch 11/100
# 100/100 - 0s - loss: 10.1544 - 149ms/epoch - 1ms/step
# Epoch 12/100
# 100/100 - 0s - loss: 9.6006 - 146ms/epoch - 1ms/step
# Epoch 13/100
# 100/100 - 0s - loss: 9.0493 - 147ms/epoch - 1ms/step
# Epoch 14/100
# 100/100 - 0s - loss: 8.4988 - 152ms/epoch - 2ms/step
# Epoch 15/100
# 100/100 - 0s - loss: 7.9477 - 149ms/epoch - 1ms/step
# Epoch 16/100
# 100/100 - 0s - loss: 7.3993 - 150ms/epoch - 2ms/step
# Epoch 17/100
# 100/100 - 0s - loss: 6.8516 - 148ms/epoch - 1ms/step
# Epoch 18/100
# 100/100 - 0s - loss: 6.3045 - 158ms/epoch - 2ms/step
# Epoch 19/100
# 100/100 - 0s - loss: 5.7605 - 159ms/epoch - 2ms/step
# Epoch 20/100
# 100/100 - 0s - loss: 5.2175 - 150ms/epoch - 1ms/step
# Epoch 21/100
# 100/100 - 0s - loss: 4.6773 - 158ms/epoch - 2ms/step
# Epoch 22/100
# 100/100 - 0s - loss: 4.1418 - 149ms/epoch - 1ms/step
# Epoch 23/100
# 100/100 - 0s - loss: 3.6094 - 149ms/epoch - 1ms/step
# Epoch 24/100
# 100/100 - 0s - loss: 3.0820 - 156ms/epoch - 2ms/step
# Epoch 25/100
# 100/100 - 0s - loss: 2.5608 - 151ms/epoch - 2ms/step
# Epoch 26/100
# 100/100 - 0s - loss: 2.0466 - 147ms/epoch - 1ms/step
# Epoch 27/100
# 100/100 - 0s - loss: 1.5460 - 148ms/epoch - 1ms/step
# Epoch 28/100
# 100/100 - 0s - loss: 1.0708 - 149ms/epoch - 1ms/step
# Epoch 29/100
# 100/100 - 0s - loss: 0.6550 - 148ms/epoch - 1ms/step
# Epoch 30/100
# 100/100 - 0s - loss: 0.3629 - 148ms/epoch - 1ms/step
# Epoch 31/100
# 100/100 - 0s - loss: 0.2264 - 156ms/epoch - 2ms/step
# Epoch 32/100
# 100/100 - 0s - loss: 0.1820 - 148ms/epoch - 1ms/step
# Epoch 33/100
# 100/100 - 0s - loss: 0.1709 - 150ms/epoch - 1ms/step
# Epoch 34/100
# 100/100 - 0s - loss: 0.1689 - 149ms/epoch - 1ms/step
# Epoch 35/100
# 100/100 - 0s - loss: 0.1685 - 149ms/epoch - 1ms/step
# Epoch 36/100
# 100/100 - 0s - loss: 0.1685 - 147ms/epoch - 1ms/step
# Epoch 37/100
# 100/100 - 0s - loss: 0.1686 - 161ms/epoch - 2ms/step
# Epoch 38/100
# 100/100 - 0s - loss: 0.1685 - 148ms/epoch - 1ms/step
# Epoch 39/100
# 100/100 - 0s - loss: 0.1685 - 146ms/epoch - 1ms/step
# Epoch 40/100
# 100/100 - 0s - loss: 0.1684 - 147ms/epoch - 1ms/step
# Epoch 41/100
# 100/100 - 0s - loss: 0.1686 - 146ms/epoch - 1ms/step
# Epoch 42/100
# 100/100 - 0s - loss: 0.1684 - 145ms/epoch - 1ms/step
# Epoch 43/100
# 100/100 - 0s - loss: 0.1684 - 149ms/epoch - 1ms/step
# Epoch 44/100
# 100/100 - 0s - loss: 0.1685 - 153ms/epoch - 2ms/step
# Epoch 45/100
# 100/100 - 0s - loss: 0.1685 - 145ms/epoch - 1ms/step
# Epoch 46/100
# 100/100 - 0s - loss: 0.1684 - 152ms/epoch - 2ms/step
# Epoch 47/100
# 100/100 - 0s - loss: 0.1686 - 147ms/epoch - 1ms/step
# Epoch 48/100
# 100/100 - 0s - loss: 0.1688 - 145ms/epoch - 1ms/step
# Epoch 49/100
# 100/100 - 0s - loss: 0.1685 - 154ms/epoch - 2ms/step
# Epoch 50/100
# 100/100 - 0s - loss: 0.1687 - 146ms/epoch - 1ms/step
# Epoch 51/100
# 100/100 - 0s - loss: 0.1685 - 142ms/epoch - 1ms/step
# Epoch 52/100
# 100/100 - 0s - loss: 0.1687 - 132ms/epoch - 1ms/step
# Epoch 53/100
# 100/100 - 0s - loss: 0.1690 - 144ms/epoch - 1ms/step
# Epoch 54/100
# 100/100 - 0s - loss: 0.1687 - 147ms/epoch - 1ms/step
# Epoch 55/100
# 100/100 - 0s - loss: 0.1684 - 152ms/epoch - 2ms/step
# Epoch 56/100
# 100/100 - 0s - loss: 0.1686 - 147ms/epoch - 1ms/step
# Epoch 57/100
# 100/100 - 0s - loss: 0.1689 - 149ms/epoch - 1ms/step
# Epoch 58/100
# 100/100 - 0s - loss: 0.1685 - 152ms/epoch - 2ms/step
# Epoch 59/100
# 100/100 - 0s - loss: 0.1691 - 154ms/epoch - 2ms/step
# Epoch 60/100
# 100/100 - 0s - loss: 0.1686 - 150ms/epoch - 2ms/step
# Epoch 61/100
# 100/100 - 0s - loss: 0.1687 - 150ms/epoch - 2ms/step
# Epoch 62/100
# 100/100 - 0s - loss: 0.1687 - 148ms/epoch - 1ms/step
# Epoch 63/100
# 100/100 - 0s - loss: 0.1691 - 149ms/epoch - 1ms/step
# Epoch 64/100
# 100/100 - 0s - loss: 0.1683 - 154ms/epoch - 2ms/step
# Epoch 65/100
# 100/100 - 0s - loss: 0.1689 - 155ms/epoch - 2ms/step
# Epoch 66/100
# 100/100 - 0s - loss: 0.1689 - 148ms/epoch - 1ms/step
# Epoch 67/100
# 100/100 - 0s - loss: 0.1690 - 136ms/epoch - 1ms/step
# Epoch 68/100
# 100/100 - 0s - loss: 0.1687 - 145ms/epoch - 1ms/step
# Epoch 69/100
# 100/100 - 0s - loss: 0.1691 - 147ms/epoch - 1ms/step
# Epoch 70/100
# 100/100 - 0s - loss: 0.1689 - 145ms/epoch - 1ms/step
# Epoch 71/100
# 100/100 - 0s - loss: 0.1687 - 147ms/epoch - 1ms/step
# Epoch 72/100
# 100/100 - 0s - loss: 0.1689 - 157ms/epoch - 2ms/step
# Epoch 73/100
# 100/100 - 0s - loss: 0.1689 - 149ms/epoch - 1ms/step
# Epoch 74/100
# 100/100 - 0s - loss: 0.1690 - 160ms/epoch - 2ms/step
# Epoch 75/100
# 100/100 - 0s - loss: 0.1692 - 158ms/epoch - 2ms/step
# Epoch 76/100
# 100/100 - 0s - loss: 0.1690 - 156ms/epoch - 2ms/step
# Epoch 77/100
# 100/100 - 0s - loss: 0.1690 - 150ms/epoch - 2ms/step
# Epoch 78/100
# 100/100 - 0s - loss: 0.1688 - 148ms/epoch - 1ms/step
# Epoch 79/100
# 100/100 - 0s - loss: 0.1689 - 151ms/epoch - 2ms/step
# Epoch 80/100
# 100/100 - 0s - loss: 0.1691 - 149ms/epoch - 1ms/step
# Epoch 81/100
# 100/100 - 0s - loss: 0.1686 - 150ms/epoch - 2ms/step
# Epoch 82/100
# 100/100 - 0s - loss: 0.1691 - 151ms/epoch - 2ms/step
# Epoch 83/100
# 100/100 - 0s - loss: 0.1684 - 150ms/epoch - 1ms/step
# Epoch 84/100
# 100/100 - 0s - loss: 0.1687 - 149ms/epoch - 1ms/step
# Epoch 85/100
# 100/100 - 0s - loss: 0.1690 - 151ms/epoch - 2ms/step
# Epoch 86/100
# 100/100 - 0s - loss: 0.1685 - 145ms/epoch - 1ms/step
# Epoch 87/100
# 100/100 - 0s - loss: 0.1688 - 150ms/epoch - 1ms/step
# Epoch 88/100
# 100/100 - 0s - loss: 0.1688 - 147ms/epoch - 1ms/step
# Epoch 89/100
# 100/100 - 0s - loss: 0.1690 - 149ms/epoch - 1ms/step
# Epoch 90/100
# 100/100 - 0s - loss: 0.1694 - 148ms/epoch - 1ms/step
# Epoch 91/100
# 100/100 - 0s - loss: 0.1693 - 148ms/epoch - 1ms/step
# Epoch 92/100
# 100/100 - 0s - loss: 0.1688 - 151ms/epoch - 2ms/step
# Epoch 93/100
# 100/100 - 0s - loss: 0.1685 - 152ms/epoch - 2ms/step
# Epoch 94/100
# 100/100 - 0s - loss: 0.1686 - 151ms/epoch - 2ms/step
# Epoch 95/100
# 100/100 - 0s - loss: 0.1684 - 152ms/epoch - 2ms/step
# Epoch 96/100
# 100/100 - 0s - loss: 0.1686 - 149ms/epoch - 1ms/step
# Epoch 97/100
# 100/100 - 0s - loss: 0.1688 - 151ms/epoch - 2ms/step
# Epoch 98/100
# 100/100 - 0s - loss: 0.1689 - 150ms/epoch - 2ms/step
# Epoch 99/100
# 100/100 - 0s - loss: 0.1690 - 149ms/epoch - 1ms/step
# Epoch 100/100
# 100/100 - 0s - loss: 0.1688 - 147ms/epoch - 1ms/step

# %% [markdown]
# #### Extract the weights and bias
# our actual equation is 2x - 3z + 5 + noise

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 1.9968292],
#         [-2.997725 ]], dtype=float32),
#  array([-0.00948432], dtype=float32)]

# %%
model.layers[0].get_weights()[0]
# Out:
# array([[ 1.9938639],
#        [-2.9972506]], dtype=float32)

# %%
model.layers[0].get_weights()[1]
# Out:
# array([-0.00051713], dtype=float32)

# %% [markdown]
# #### Extract outputs (make predictions)

# %%
model.predict_on_batch(training_data['inputs']).round(1)
# Out:
# array([[-11.8],
#        [  7.6],
#        [  0.1],
#        [ 24.1],
#        [ 14.1],
#        [  1.1],
#        [ 12.2],
#        [-10.7],
#        [ 21.3],
#        [ 13.3],
#        [-19.8],
#        [ 30.5],
#        [  5.8],
#        [-10. ],
#        [ -9. ],
#        [ -3. ],
#        [ -8.9],
#        [  7.5],
#        [  2.5],
#        [-26.9],
#        [ 30. ],
#        [ 19.9],
#        [ -6. ],
#        [ 13.6],
#        [  3.5],
#        [ 12.2],
#        [ 16.9],
#        [  9.1],
#        [-14.3],
#        [ -2.4],
#        [ 41.7],
#        [  4.8],
#        [ 45.8],
#        [-15.2],
#        [  1.6],
#        [ 30.9],
#        [ 14.5],
#        [-17.8],
#        [  5.2],
#        [ -3.3],
#        [ 18.1],
#        [-20.9],
#        [ -5.3],
#        [ 29.7],
#        [ 32.8],
#        [  3.2],
#        [-22.1],
#        [-10.4],
#        [ 31.3],
#        [ 30.8],
#        [-15.5],
#        [-19.6],
#        [  3.6],
#        [ -8.3],
#        [-44.3],
#        [ -8.4],
#        [  6.9],
#        [ -2.8],
#        [-13.6],
#        [ 19.6],
#        [ -3.1],
#        [  9.9],
#        [-15.8],
#        [-19. ],
#        [-38.5],
#        [  4.3],
#        [ 12.9],
#        [  8.9],
#        [  8.2],
#        [-17.8],
#        [ 17.8],
#        [  9.6],
#        [ 18.8],
#        [ 10. ],
#        [ 20.4],
#        [ 27.2],
#        [ 17.2],
#        [-18.8],
#        [  2.8],
#        [ -1.9],
#        [-40.4],
#        [ 29.1],
#        [  3.7],
#        [ 14.8],
#        [  8.4],
#        [  3.5],
#        [  9.7],
#        [ 13.3],
#        [ -7. ],
#        [-20.5],
#        [ 17.6],
#        [ 18. ],
#        [ 39.5],
#        [-12.3],
#        [-48.1],
#        [  5.9],
#        [-31.2],
#        [ 35.3],
#        [ -5.5],
#        [  0.8],
#        [ 33.4],
#        [  7.5],
#        [  9.1],
#        [ 27.8],
#        [-43.4],
#        [-47. ],
#        [  9.2],
#        [ -7.6],
#        [-19.1],
#        [-19.6],
#        [  2.2],
#        [ 30.1],
#        [ -5.4],
#        [ 24.8],
#        [ -0.7],
#        [ 45.7],
#        [-36.3],
#        [ 14.6],
#        [ -9.4],
#        [ 13.8],
#        [  0.9],
#        [ 14.4],
#        [ 10.5],
#        [  2.3],
#        [-23. ],
#        [ 28.8],
#        [  4.9],
#        [-41.2],
#        [ 29.4],
#        [ -9.4],
#        [ 24.9],
#        [ -0.1],
#        [ 14.5],
#        [  4.5],
#        [ -3.4],
#        [-13.6],
#        [ 27.1],
#        [ -9.1],
#        [-28. ],
#        [ 14.5],
#        [ 25.9],
#        [-33.9],
#        [ 30.7],
#        [ -5.7],
#        [  1.9],
#        [ -9.9],
#        [ 28.1],
#        [-15.5],
#        [-16.5],
#        [-25.1],
#        [ 18. ],
#        [-24.5],
#        [-16.8],
#        [ 20.1],
#        [-15.9],
#        [-25.3],
#        [-21.8],
#        [ 11.8],
#        [ 10.9],
#        [  1.7],
#        [-16.7],
#        [-28.9],
#        [ -2. ],
#        [ -1. ],
#        [  2.6],
#        [-13.1],
#        [-31. ],
#        [ -9.1],
#        [-25.5],
#        [-18.4],
#        [-18. ],
#        [  4.3],
#        [-17.8],
#        [  7.5],
#        [ 24.7],
#        [ 17. ],
#        [  4.8],
#        [ -6.9],
#        [ 15.8],
#        [-20.2],
#        [  9. ],
#        [ -9.3],
#        [-17.7],
#        [-11.7],
#        [-18.9],
#        [  4.6],
#        [ -0.5],
#        [  5.9],
#        [ 40.7],
#        [  3.9],
#        [  1.1],
#        [-10.2],
#        [  2.8],
#        [ 39.6],
#        [  1.9],
#        [ -9.6],
#        [ -6.3],
#        [  4.1],
#        [ 27.9],
#        [ -6.1],
#        [ 21.6],
#        [ 15.5],
#        [ 17.2],
#        [ 11.1],
#        [ 27. ],
#        [-22.1],
#        [ 18.9],
#        [-41.3],
#        [-30.1],
#        [-22.9],
#        [-23.4],
#        [ -5.1],
#        [-39.4],
#        [ 11.2],
#        [  9.3],
#        [-20.8],
#        [-40.1],
#        [ -1.4],
#        [  7.3],
#        [ 29.2],
#        [  1.2],
#        [-14.9],
#        [-13.2],
#        [ 39.5],
#        [ -7. ],
#        [ 29. ],
#        [ 29.7],
#        [  8.3],
#        [-17. ],
#        [-35.4],
#        [ 14.3],
#        [ -5.8],
#        [ -7.6],
#        [ 27.7],
#        [ 11.7],
#        [  5.3],
#        [ 21.1],
#        [ -3.3],
#        [-11.5],
#        [-10.9],
#        [  6.8],
#        [-30.3],
#        [-15.3],
#        [-15.9],
#        [ 36.7],
#        [-33.5],
#        [-12.3],
#        [ 15.1],
#        [ -6.1],
#        [ 22.5],
#        [  5. ],
#        [ 12.4],
#        [-19.2],
#        [-30.8],
#        [ -7.7],
#        [ -6.8],
#        [-21.9],
#        [ -5.3],
#        [ -6.5],
#        [  2.2],
#        [ -7.2],
#        [-10.2],
#        [ 27. ],
#        [ 10.2],
#        [ -3.2],
#        [  6.8],
#        [ 38.5],
#        [ 20.4],
#        [-25.6],
#        [-16.3],
#        [  0.2],
#        [  2.5],
#        [ -1.9],
#        [ -2.1],
#        [ 18.3],
#        [ 17.9],
#        [ 22.3],
#        [-29.1],
#        [ 18.3],
#        [ 14.8],
#        [ 20.5],
#        [ 11.4],
#        [-13.3],
#        [-29.5],
#        [  5.7],
#        [ 18.3],
#        [  8.1],
#        [-19. ],
#        [-14.9],
#        [-18.4],
#        [ 13.5],
#        [-16.6],
#        [ -7.3],
#        [-11.5],
#        [-16.1],
#        [ 31. ],
#        [  9.8],
#        [  4.4],
#        [  9.6],
#        [-26.9],
#        [ -1. ],
#        [ 12. ],
#        [ -0.6],
#        [ 36.6],
#        [-10.8],
#        [-35.3],
#        [ 10.8],
#        [  1.7],
#        [ 45.7],
#        [  8. ],
#        [ 34.3],
#        [  4.7],
#        [ 25.9],
#        [-28.5],
#        [-29.2],
#        [ -9.9],
#        [  6.9],
#        [ 16.6],
#        [ -7. ],
#        [  8.3],
#        [ -9.7],
#        [  5.2],
#        [-20.7],
#        [  1.2],
#        [-31.5],
#        [  3.5],
#        [ 13.4],
#        [ -4.6],
#        [  8.4],
#        [ 16.2],
#        [-42.7],
#        [ 27.9],
#        [  6.6],
#        [-29.7],
#        [ -8.9],
#        [ -0.6],
#        [-41.1],
#        [ 10.8],
#        [ 22. ],
#        [-20.8],
#        [-27.5],
#        [ 25.2],
#        [ 41.3],
#        [  9.2],
#        [ 38.4],
#        [-19.8],
#        [  0.2],
#        [ 25.9],
#        [-10.6],
#        [-18. ],
#        [ 30.2],
#        [-27.2],
#        [ -0.9],
#        [ 16.9],
#        [-48.9],
#        [ 19.8],
#        [-11.5],
#        [-20.3],
#        [ 32.3],
#        [ -2.4],
#        [ 26.5],
#        [ 18.7],
#        [-24.5],
#        [ -0.1],
#        [-32.8],
#        [ 43.8],
#        [ -6.4],
#        [  6.1],
#        [-32.9],
#        [ -4.9],
#        [-16.5],
#        [ 17.2],
#        [-11.8],
#        [ 44.9],
#        [ -3.2],
#        [  2.4],
#        [-18.9],
#        [  3.8],
#        [-27.5],
#        [ 17.7],
#        [ -5.4],
#        [-27.6],
#        [  5.2],
#        [  3.4],
#        [  9.1],
#        [  1.1],
#        [ 33.5],
#        [ -8. ],
#        [ 41.5],
#        [-26.2],
#        [ 20.3],
#        [  1.6],
#        [ 19.2],
#        [ 15.7],
#        [ 30.5],
#        [ -5.7],
#        [-35.3],
#        [ -8. ],
#        [-22.7],
#        [ 35.9],
#        [ -9. ],
#        [  1.1],
#        [ -9.2],
#        [-33.5],
#        [  7.9],
#        [  2.3],
#        [-46.4],
#        [  5. ],
#        [-12.4],
#        [ -9. ],
#        [ -3.7],
#        [ 27.1],
#        [ 24.1],
#        [ -4.1],
#        [-15.9],
#        [  2.9],
#        [  4.2],
#        [-15.8],
#        [ -9.8],
#        [-18.8],
#        [-30.4],
#        [-32.2],
#        [-22.1],
#        [  1.7],
#        [ -8.6],
#        [-28.4],
#        [-34.3],
#        [ 26.2],
#        [ -8.7],
#        [ 27.5],
#        [ 21.7],
#        [-40.3],
#        [ -4. ],
#        [-12.2],
#        [ -4.7],
#        [  7.9],
#        [-37.6],
#        [-11.6],
#        [-22.1],
#        [-20.8],
#        [-12.3],
#        [-12.8],
#        [-23. ],
#        [-30.8],
#        [  8.4],
#        [ -3.3],
#        [ -7.5],
#        [ 22.2],
#        [-44.4],
#        [-26.7],
#        [-17.4],
#        [  0.8],
#        [ 24. ],
#        [  5.5],
#        [-23.2],
#        [ -9.9],
#        [-36.7],
#        [ 25.9],
#        [ 14.9],
#        [-25.5],
#        [-48.8],
#        [ 16.8],
#        [-16.5],
#        [  0.4],
#        [-22.7],
#        [  6.4],
#        [-44.2],
#        [-28.6],
#        [ 14.7],
#        [-11.6],
#        [ 24.8],
#        [  1.4],
#        [ -1. ],
#        [ 13.2],
#        [ -4.3],
#        [-11.9],
#        [-14.8],
#        [ 14.2],
#        [ 23.2],
#        [-25.7],
#        [-27.9],
#        [-10.9],
#        [ 30.8],
#        [ -5.1],
#        [  5.8],
#        [  4.7],
#        [ 33.5],
#        [ 29.4],
#        [ 25. ],
#        [  4.1],
#        [ 26.8],
#        [-29.2],
#        [-39. ],
#        [ 10.7],
#        [-33.1],
#        [-20.8],
#        [ 37.1],
#        [ 16.8],
#        [-20.4],
#        [-25. ],
#        [-36.5],
#        [ -8.7],
#        [-33.5],
#        [ 40.7],
#        [  9.2],
#        [-11.6],
#        [ 30.8],
#        [ -8.7],
#        [ 13.3],
#        [-27.8],
#        [ -8.5],
#        [ -0.5],
#        [ 17.5],
#        [ 33.9],
#        [ 18.7],
#        [ 35.1],
#        [ -1. ],
#        [ 27.5],
#        [-12. ],
#        [ -4.4],
#        [-17.9],
#        [ 23.4],
#        [-20.1],
#        [ -9.4],
#        [ -1.5],
#        [-38.9],
#        [  2.3],
#        [ 15.1],
#        [ -6.9],
#        [-16.4],
#        [ 47.5],
#        [-23.9],
#        [  4. ],
#        [  4.4],
#        [ -9.4],
#        [ -2.8],
#        [-17.8],
#        [ -3.9],
#        [ 15.1],
#        [-17.3],
#        [ -4.7],
#        [ -2.6],
#        [  3.2],
#        [ -3.7],
#        [ 12.8],
#        [  0.5],
#        [ 33.7],
#        [ -5.4],
#        [-38.4],
#        [-32.3],
#        [ 21.3],
#        [  6.6],
#        [-13. ],
#        [ -9.2],
#        [-19.1],
#        [ -6.6],
#        [ -1.8],
#        [ 47.1],
#        [  2.9],
#        [ -8.2],
#        [-34.8],
#        [ 16.8],
#        [ 26.6],
#        [ 22.9],
#        [ 40.4],
#        [  1.2],
#        [ -7.5],
#        [ 26.5],
#        [ 19.2],
#        [ 40.6],
#        [  9. ],
#        [-20.7],
#        [ 31.3],
#        [-25.8],
#        [ 41.4],
#        [ 12.9],
#        [  4. ],
#        [-14.4],
#        [-33.7],
#        [ 27.8],
#        [ -2.8],
#        [-41.2],
#        [ -1.6],
#        [-29.6],
#        [-19. ],
#        [  2.7],
#        [-35.6],
#        [ 22.7],
#        [ 43.4],
#        [ 20.1],
#        [-11.9],
#        [  8.8],
#        [-15.5],
#        [ 15.5],
#        [ 26.7],
#        [ 23.6],
#        [ -8.1],
#        [-24.1],
#        [-12. ],
#        [-14.5],
#        [ 17.3],
#        [  1.5],
#        [-28.5],
#        [-11.3],
#        [-20.5],
#        [-38.6],
#        [ 24.5],
#        [ 44. ],
#        [-17.7],
#        [ 30.8],
#        [ 22.1],
#        [  5.7],
#        [ 27.4],
#        [-33.1],
#        [-43.7],
#        [-11.5],
#        [-10.7],
#        [-18.5],
#        [ 10.3],
#        [-19. ],
#        [-25.9],
#        [ 15.1],
#        [-37.9],
#        [ 13.5],
#        [-10.6],
#        [-15.7],
#        [ 34.4],
#        [ -2.5],
#        [-32.8],
#        [  8.3],
#        [-30.4],
#        [ -0.5],
#        [-36.7],
#        [ -8.3],
#        [  3.5],
#        [-13.4],
#        [ 15.5],
#        [-11.9],
#        [-17.6],
#        [  1.1],
#        [ 28. ],
#        [ 29.4],
#        [-12.6],
#        [  1.3],
#        [ -9. ],
#        [  9.7],
#        [ -0.8],
#        [-22. ],
#        [ 40.8],
#        [ 12.7],
#        [-18.9],
#        [  5.3],
#        [-22.5],
#        [-39.2],
#        [-12.1],
#        [-41.3],
#        [ 21.1],
#        [ 13.2],
#        [ -7.1],
#        [ 17.2],
#        [  9.5],
#        [ -7. ],
#        [  8.8],
#        [-33.9],
#        [ 28.2],
#        [-16.5],
#        [ -1.7],
#        [ 41.6],
#        [ 25.4],
#        [ -3.3],
#        [  4.4],
#        [  7.1],
#        [  4.3],
#        [-26.6],
#        [-24.3],
#        [  7.9],
#        [  5.4],
#        [-18.4],
#        [-32.3],
#        [ 24.3],
#        [ 32.9],
#        [-10. ],
#        [  2.8],
#        [-32.8],
#        [-39.9],
#        [ 36.1],
#        [ 14.2],
#        [ -8.4],
#        [ -1.1],
#        [  4.6],
#        [ 18.7],
#        [ -0.4],
#        [  0.4],
#        [ 26.5],
#        [-37.9],
#        [ 16.3],
#        [-10.7],
#        [-17.2],
#        [ 19.8],
#        [ 28. ],
#        [ 19.4],
#        [ 22.8],
#        [ -5.8],
#        [ -8.2],
#        [ -2.5],
#        [ 12.2],
#        [  1.2],
#        [  5.2],
#        [-18.1],
#        [ -1.5],
#        [ 14.3],
#        [  9.6],
#        [ -1.1],
#        [ -7.7],
#        [ 23.4],
#        [ -8.9],
#        [-41.2],
#        [-34.4],
#        [ 17.7],
#        [  9.7],
#        [-43.3],
#        [-31.5],
#        [-25.4],
#        [ -3.9],
#        [ 14.4],
#        [-17.2],
#        [ -4.8],
#        [ -3.1],
#        [ 11.9],
#        [ -7.3],
#        [-38.6],
#        [  0.7],
#        [-11.8],
#        [-19.3],
#        [-24.1],
#        [-36.1],
#        [ 27.6],
#        [ 16.3],
#        [  3.8],
#        [  9.9],
#        [ -1.4],
#        [  1.5],
#        [-18.3],
#        [-10.6],
#        [ 30.9],
#        [-30.1],
#        [ -6.4],
#        [-26.2],
#        [-13.6],
#        [ 11. ],
#        [ -4.2],
#        [-40.4],
#        [-26. ],
#        [-14. ],
#        [-30.6],
#        [-17. ],
#        [ 35.1],
#        [ 25.8],
#        [ 22.4],
#        [ -3.7],
#        [ 37.2],
#        [ 31.9],
#        [-21.4],
#        [ -3.9],
#        [-35.1],
#        [-23.8],
#        [ -0.6],
#        [ 25.8],
#        [-14.3],
#        [ 18.4],
#        [ -0.5],
#        [  6. ],
#        [-16. ],
#        [ -8.6],
#        [  5.2],
#        [ 24.2],
#        [ 30.4],
#        [ -6.9],
#        [-15.7],
#        [ 29.6],
#        [ -4.1],
#        [-19.9],
#        [-35.3],
#        [ -6.3],
#        [ 24.4],
#        [ -8.3],
#        [ 15.1],
#        [  2.8],
#        [-26. ],
#        [-21.7],
#        [-19. ],
#        [-30.9],
#        [ 16.5],
#        [ 41.8],
#        [ 32. ],
#        [ -7.4],
#        [  9.4],
#        [ 25.1],
#        [  8.5],
#        [  9.4],
#        [-28.2],
#        [  7.2],
#        [ 25.7],
#        [-10.5],
#        [ -2.6],
#        [ 27.7],
#        [  3.8],
#        [ -9. ],
#        [-38.1],
#        [-30.1],
#        [ 13.7],
#        [-20. ],
#        [-17.3],
#        [  0.1],
#        [ -6.8],
#        [-18.4],
#        [-19.6],
#        [ -0.3],
#        [-10.1],
#        [-34.4],
#        [ 16.5],
#        [-13.2],
#        [ 41.6],
#        [-26.4],
#        [ 15.6],
#        [ -3.9],
#        [ 16.5],
#        [-30.5],
#        [ 28.4],
#        [ 39.7],
#        [ -9.7],
#        [ 27.4],
#        [-37. ],
#        [ 38.5],
#        [  5.5],
#        [  5.8],
#        [ 21.9],
#        [  9.8],
#        [ -0.8],
#        [ -7.3],
#        [ 35.9],
#        [  1.5],
#        [-19.6],
#        [ -2.3],
#        [ 20.1],
#        [ -8.1],
#        [ 17.2],
#        [ 14.9],
#        [ -2.2],
#        [ 11.8],
#        [ -3.6],
#        [ 12.1],
#        [ -5.6],
#        [  9.2],
#        [ -7.7],
#        [ 13.2],
#        [  8.6],
#        [-12.8],
#        [-41.4],
#        [ -8.7],
#        [ -8.7],
#        [-18.1],
#        [ 22.5],
#        [-21.8],
#        [ 21.2],
#        [-16.7],
#        [ 37.6],
#        [ 34.8],
#        [ 11.2],
#        [ 26.6],
#        [  4.6],
#        [ -4.2],
#        [-10.8],
#        [ 32.6],
#        [-28.2],
#        [ 23.7],
#        [ -7.3],
#        [ 30.9],
#        [  2.7],
#        [ 16.6],
#        [  6.4],
#        [ 21.8],
#        [ 11.4],
#        [ 17.5],
#        [-22.7],
#        [-24. ],
#        [ 18.2],
#        [ 27.1],
#        [-10.8],
#        [-32.3],
#        [ 16.5],
#        [ -6.8],
#        [  8.2],
#        [ 29.1],
#        [  8.7],
#        [-12.1],
#        [ 45.3],
#        [ 30.6],
#        [ -8.2],
#        [ 44.4],
#        [  4.9],
#        [ 26.5],
#        [ -5.4],
#        [ -1.8],
#        [ -9.6],
#        [  9.4],
#        [ 36.3],
#        [ -7.8],
#        [-20.5],
#        [ 47.7],
#        [ -9.7],
#        [-17.8],
#        [  2.5],
#        [-25.2],
#        [ 22.3],
#        [ -6.7],
#        [ -9.7],
#        [ -7.2],
#        [-27.9],
#        [-26.2],
#        [  1.3],
#        [ -3.7],
#        [-13.8],
#        [-10.8],
#        [ 23.8],
#        [  1.8],
#        [-36.8],
#        [ -3.1],
#        [ -5.1],
#        [  4.5],
#        [-40.7],
#        [  0. ],
#        [ 15.3],
#        [ 24. ],
#        [ 19.5],
#        [-13.3],
#        [ 15.6],
#        [  9. ],
#        [ -3.3],
#        [  1.2],
#        [  1. ],
#        [ 22.6],
#        [-16.4],
#        [ -2.7],
#        [ -8.2],
#        [-14.7],
#        [ -4.8],
#        [ -7.8],
#        [ 28.4],
#        [ 27.1],
#        [ 12.1],
#        [ 27.5],
#        [ -2.4],
#        [ 15.8],
#        [ -6.3],
#        [-18.4],
#        [ 27.8],
#        [ -0.4],
#        [  7.7],
#        [-23.7],
#        [  8.1],
#        [ 12.3],
#        [  8.8],
#        [ -6.4],
#        [ 21.8],
#        [ -3.1],
#        [  0.2],
#        [-18.5],
#        [ -3.6],
#        [  2. ],
#        [-10.9],
#        [  2.5],
#        [  8.4],
#        [ -2.1],
#        [ -5.5],
#        [ -3.3],
#        [  1. ],
#        [ 12.1],
#        [ 26.6],
#        [ -0.8],
#        [-12.8],
#        [  8.8],
#        [  8.6],
#        [-31.8],
#        [ -8.9],
#        [-23. ],
#        [  1.9],
#        [  3.7],
#        [ 32.2],
#        [  8.2],
#        [ -2.6],
#        [-31.1],
#        [  5.5],
#        [-19.4],
#        [ -6.8],
#        [ -7.5],
#        [ 20.4],
#        [  4.8],
#        [ 20.5],
#        [ -2.9]], dtype=float32)

# %%
training_data['targets'].round(1)
# Out:
# array([[-10.9],
#        [  6.8],
#        [ -0.2],
#        [ 24.4],
#        [ 13.2],
#        [  1.7],
#        [ 12.3],
#        [-11.3],
#        [ 21.5],
#        [ 12.7],
#        [-20.8],
#        [ 31.2],
#        [  4.9],
#        [-10.6],
#        [ -8.2],
#        [ -2.4],
#        [ -8. ],
#        [  8.2],
#        [  2.3],
#        [-27.9],
#        [ 30.6],
#        [ 20.1],
#        [ -5.6],
#        [ 13. ],
#        [  4.3],
#        [ 11.4],
#        [ 16.3],
#        [  8.5],
#        [-14.5],
#        [ -2.2],
#        [ 42.5],
#        [  4.1],
#        [ 45.6],
#        [-14.8],
#        [  0.7],
#        [ 31.7],
#        [ 14.7],
#        [-17.9],
#        [  4.8],
#        [ -3.9],
#        [ 18.8],
#        [-20. ],
#        [ -6. ],
#        [ 30.1],
#        [ 33.1],
#        [  4.1],
#        [-21.7],
#        [ -9.9],
#        [ 30.7],
#        [ 30.6],
#        [-14.6],
#        [-18.8],
#        [  3.8],
#        [ -7.6],
#        [-43.9],
#        [ -8.7],
#        [  6.4],
#        [ -2.5],
#        [-13.4],
#        [ 19.9],
#        [ -2.4],
#        [ 10.7],
#        [-16.6],
#        [-19.5],
#        [-38.6],
#        [  3.5],
#        [ 13. ],
#        [  9.7],
#        [  7.7],
#        [-17.9],
#        [ 17.4],
#        [ 10.4],
#        [ 18.1],
#        [ 10.2],
#        [ 20.4],
#        [ 27. ],
#        [ 17.6],
#        [-18.3],
#        [  2.6],
#        [ -1. ],
#        [-41. ],
#        [ 28.3],
#        [  3.9],
#        [ 15.8],
#        [  8.1],
#        [  3.4],
#        [  9.2],
#        [ 13.7],
#        [ -8. ],
#        [-20.6],
#        [ 17.7],
#        [ 18.1],
#        [ 38.8],
#        [-13.1],
#        [-48.9],
#        [  6.8],
#        [-31.6],
#        [ 35.7],
#        [ -5.6],
#        [  0.6],
#        [ 34.4],
#        [  7.2],
#        [  9.2],
#        [ 26.9],
#        [-44.2],
#        [-46.8],
#        [  8.4],
#        [ -8.4],
#        [-18.7],
#        [-19.2],
#        [  1.4],
#        [ 30.1],
#        [ -4.6],
#        [ 24.6],
#        [ -1.6],
#        [ 45.6],
#        [-35.4],
#        [ 15.4],
#        [-10.2],
#        [ 13.4],
#        [  0.6],
#        [ 14.4],
#        [ 10.5],
#        [  1.7],
#        [-22.3],
#        [ 28.1],
#        [  4.4],
#        [-40.5],
#        [ 28.9],
#        [ -9.4],
#        [ 24. ],
#        [  0.8],
#        [ 14.1],
#        [  3.6],
#        [ -4.1],
#        [-14.6],
#        [ 27.8],
#        [ -9.1],
#        [-28.3],
#        [ 15.4],
#        [ 25.4],
#        [-33.2],
#        [ 30.1],
#        [ -6.6],
#        [  2.3],
#        [ -9.8],
#        [ 27.9],
#        [-15.4],
#        [-16.7],
#        [-25.5],
#        [ 19. ],
#        [-24.2],
#        [-17.3],
#        [ 21. ],
#        [-16. ],
#        [-25.5],
#        [-21.6],
#        [ 11.6],
#        [ 10.9],
#        [  1.1],
#        [-17.4],
#        [-28.5],
#        [ -1.3],
#        [ -0.1],
#        [  3.1],
#        [-13.6],
#        [-30.7],
#        [ -8.3],
#        [-24.8],
#        [-18. ],
#        [-18.3],
#        [  4.1],
#        [-18. ],
#        [  6.8],
#        [ 24.8],
#        [ 16.1],
#        [  5. ],
#        [ -6.3],
#        [ 14.8],
#        [-19.8],
#        [  9. ],
#        [ -8.8],
#        [-17.5],
#        [-12.3],
#        [-19. ],
#        [  4.2],
#        [  0.4],
#        [  5.6],
#        [ 40. ],
#        [  3.7],
#        [  1.9],
#        [-10.7],
#        [  2. ],
#        [ 39.6],
#        [  2.1],
#        [ -9.6],
#        [ -5.5],
#        [  4.6],
#        [ 28.4],
#        [ -6. ],
#        [ 21.4],
#        [ 14.8],
#        [ 17.5],
#        [ 11.7],
#        [ 27.5],
#        [-23.1],
#        [ 20. ],
#        [-41.4],
#        [-29.3],
#        [-22.3],
#        [-23.2],
#        [ -5.5],
#        [-40.2],
#        [ 11.9],
#        [  8.3],
#        [-21.2],
#        [-39.5],
#        [ -0.7],
#        [  8.1],
#        [ 28.3],
#        [  2.1],
#        [-14.4],
#        [-12.3],
#        [ 38.7],
#        [ -6.7],
#        [ 28.7],
#        [ 30. ],
#        [  7.8],
#        [-16.1],
#        [-34.8],
#        [ 14.2],
#        [ -6.3],
#        [ -6.8],
#        [ 28.1],
#        [ 12. ],
#        [  5. ],
#        [ 21.2],
#        [ -3.9],
#        [-12. ],
#        [-11.4],
#        [  7.5],
#        [-29.9],
#        [-16. ],
#        [-16.6],
#        [ 37.2],
#        [-34.3],
#        [-12.6],
#        [ 16. ],
#        [ -6.3],
#        [ 23.2],
#        [  4.6],
#        [ 13.4],
#        [-18.6],
#        [-31.1],
#        [ -8.2],
#        [ -5.9],
#        [-21.2],
#        [ -5.8],
#        [ -6.2],
#        [  3. ],
#        [ -6.7],
#        [ -9.7],
#        [ 27.4],
#        [ 10.1],
#        [ -2.9],
#        [  7.5],
#        [ 38.5],
#        [ 20.1],
#        [-25.2],
#        [-17.1],
#        [ -0. ],
#        [  3. ],
#        [ -1.8],
#        [ -2.9],
#        [ 17.5],
#        [ 17.7],
#        [ 21.7],
#        [-29.5],
#        [ 17.9],
#        [ 15.5],
#        [ 19.9],
#        [ 11.2],
#        [-13. ],
#        [-30.1],
#        [  5.6],
#        [ 18.8],
#        [  8. ],
#        [-18.2],
#        [-14.6],
#        [-18.7],
#        [ 13.8],
#        [-16.1],
#        [ -7.4],
#        [-10.8],
#        [-16.3],
#        [ 32. ],
#        [  9.3],
#        [  4.1],
#        [ 10. ],
#        [-27.1],
#        [ -1.6],
#        [ 12.7],
#        [ -0.5],
#        [ 35.8],
#        [-10.7],
#        [-34.7],
#        [ 10.9],
#        [  1.9],
#        [ 45.3],
#        [  7.2],
#        [ 33.8],
#        [  5.6],
#        [ 26.3],
#        [-28. ],
#        [-30. ],
#        [-10.3],
#        [  6.6],
#        [ 15.6],
#        [ -6.2],
#        [  7.9],
#        [-10.2],
#        [  5.9],
#        [-20.2],
#        [  0.9],
#        [-31.9],
#        [  3.9],
#        [ 13.6],
#        [ -4.5],
#        [  8.1],
#        [ 16.2],
#        [-42.6],
#        [ 27.6],
#        [  7. ],
#        [-30.4],
#        [ -9.6],
#        [  0.4],
#        [-40.9],
#        [ 10.4],
#        [ 22.3],
#        [-21. ],
#        [-27.7],
#        [ 25.6],
#        [ 40.9],
#        [ 10.1],
#        [ 37.9],
#        [-20.4],
#        [  0.1],
#        [ 26.9],
#        [-10.4],
#        [-17.3],
#        [ 30.9],
#        [-26.9],
#        [ -1. ],
#        [ 17.5],
#        [-49. ],
#        [ 19.7],
#        [-11.8],
#        [-19.8],
#        [ 31.6],
#        [ -3.1],
#        [ 26.1],
#        [ 17.8],
#        [-23.9],
#        [  0.8],
#        [-31.9],
#        [ 44.7],
#        [ -6.3],
#        [  6.8],
#        [-33.9],
#        [ -4.1],
#        [-16.8],
#        [ 16.8],
#        [-12. ],
#        [ 45.6],
#        [ -2.4],
#        [  2.3],
#        [-18. ],
#        [  3.1],
#        [-27.2],
#        [ 17.9],
#        [ -5.4],
#        [-26.7],
#        [  5.1],
#        [  3.4],
#        [ 10. ],
#        [  0.2],
#        [ 32.9],
#        [ -8.7],
#        [ 40.9],
#        [-26.1],
#        [ 20.9],
#        [  2.3],
#        [ 19.2],
#        [ 16.6],
#        [ 29.9],
#        [ -5.7],
#        [-34.9],
#        [ -8.3],
#        [-22.9],
#        [ 35. ],
#        [ -9.6],
#        [  0.7],
#        [ -9.2],
#        [-33.8],
#        [  7.4],
#        [  2.1],
#        [-47.4],
#        [  5.2],
#        [-13.2],
#        [ -9.5],
#        [ -3.8],
#        [ 28. ],
#        [ 24.9],
#        [ -3.9],
#        [-15. ],
#        [  2.2],
#        [  3.9],
#        [-16.5],
#        [-10.1],
#        [-18.3],
#        [-30. ],
#        [-32. ],
#        [-21.8],
#        [  1.1],
#        [ -7.9],
#        [-29.3],
#        [-33.7],
#        [ 26.1],
#        [ -7.8],
#        [ 27.5],
#        [ 21.3],
#        [-40.1],
#        [ -3.3],
#        [-11.6],
#        [ -5.6],
#        [  8.1],
#        [-37.4],
#        [-12.6],
#        [-22.7],
#        [-19.9],
#        [-11.7],
#        [-12.5],
#        [-22.2],
#        [-30.6],
#        [  7.7],
#        [ -3.8],
#        [ -6.7],
#        [ 22.6],
#        [-45.3],
#        [-26.5],
#        [-18.4],
#        [  0.3],
#        [ 23.6],
#        [  5.3],
#        [-22.5],
#        [ -9.9],
#        [-36.1],
#        [ 26.5],
#        [ 14.7],
#        [-25.5],
#        [-49.1],
#        [ 16.2],
#        [-15.9],
#        [  0.9],
#        [-22.4],
#        [  6.4],
#        [-44.1],
#        [-28.8],
#        [ 15.1],
#        [-12. ],
#        [ 24.7],
#        [  1.4],
#        [ -1. ],
#        [ 13.4],
#        [ -3.3],
#        [-11.6],
#        [-15. ],
#        [ 13.9],
#        [ 22.6],
#        [-25.4],
#        [-28.4],
#        [-11. ],
#        [ 30.4],
#        [ -5.3],
#        [  6.4],
#        [  5.5],
#        [ 33.8],
#        [ 29.3],
#        [ 24.4],
#        [  4.3],
#        [ 26.8],
#        [-30. ],
#        [-39.2],
#        [  9.9],
#        [-32.2],
#        [-19.8],
#        [ 37.5],
#        [ 16.1],
#        [-19.6],
#        [-25.5],
#        [-37.3],
#        [ -8. ],
#        [-34.4],
#        [ 40.4],
#        [  8.4],
#        [-10.9],
#        [ 29.9],
#        [ -8.4],
#        [ 13.1],
#        [-26.8],
#        [ -8.8],
#        [  0.2],
#        [ 17.3],
#        [ 34.6],
#        [ 19.5],
#        [ 34.1],
#        [ -0.2],
#        [ 26.9],
#        [-12.7],
#        [ -3.6],
#        [-18.3],
#        [ 22.9],
#        [-20.5],
#        [-10. ],
#        [ -1.8],
#        [-38.5],
#        [  2.3],
#        [ 14.6],
#        [ -7.8],
#        [-17.4],
#        [ 47.8],
#        [-24.5],
#        [  4.5],
#        [  4.9],
#        [-10.2],
#        [ -3.4],
#        [-17.4],
#        [ -4. ],
#        [ 14.9],
#        [-16.4],
#        [ -5. ],
#        [ -2.4],
#        [  2.7],
#        [ -2.9],
#        [ 12.5],
#        [ -0.5],
#        [ 32.8],
#        [ -5.7],
#        [-37.6],
#        [-32.5],
#        [ 21.4],
#        [  6.7],
#        [-13.1],
#        [ -8.9],
#        [-18.4],
#        [ -5.9],
#        [ -1. ],
#        [ 46.5],
#        [  2.3],
#        [ -9.1],
#        [-35.2],
#        [ 15.9],
#        [ 27.5],
#        [ 23.2],
#        [ 40. ],
#        [  1.1],
#        [ -7.1],
#        [ 26.1],
#        [ 20. ],
#        [ 39.7],
#        [  9.3],
#        [-19.7],
#        [ 30.4],
#        [-24.9],
#        [ 40.8],
#        [ 13. ],
#        [  3.8],
#        [-15.1],
#        [-33.7],
#        [ 27.7],
#        [ -1.9],
#        [-41.3],
#        [ -1.9],
#        [-29.2],
#        [-18.8],
#        [  3.5],
#        [-35.2],
#        [ 23.4],
#        [ 42.8],
#        [ 21. ],
#        [-12.1],
#        [  8.7],
#        [-14.6],
#        [ 15.8],
#        [ 26. ],
#        [ 22.7],
#        [ -8.9],
#        [-23.3],
#        [-12.5],
#        [-15.1],
#        [ 18. ],
#        [  1.1],
#        [-29.3],
#        [-10.3],
#        [-20.1],
#        [-39.5],
#        [ 23.8],
#        [ 44.2],
#        [-17. ],
#        [ 31.5],
#        [ 21.4],
#        [  5.1],
#        [ 27.9],
#        [-33.4],
#        [-43.2],
#        [-12.3],
#        [-11.3],
#        [-19.1],
#        [ 11.1],
#        [-20. ],
#        [-25.8],
#        [ 15.7],
#        [-38.1],
#        [ 12.6],
#        [-10.2],
#        [-16.7],
#        [ 34.3],
#        [ -2.5],
#        [-31.9],
#        [  8.4],
#        [-29.8],
#        [ -0.4],
#        [-37.2],
#        [ -8. ],
#        [  2.9],
#        [-14. ],
#        [ 15.7],
#        [-11.6],
#        [-18. ],
#        [  0.5],
#        [ 28.3],
#        [ 28.5],
#        [-11.9],
#        [  1.9],
#        [ -9.1],
#        [ 10.2],
#        [ -1.6],
#        [-21.9],
#        [ 40.5],
#        [ 13. ],
#        [-18.4],
#        [  4.6],
#        [-21.7],
#        [-38.8],
#        [-12.4],
#        [-40.8],
#        [ 21.2],
#        [ 13.6],
#        [ -7.4],
#        [ 16.5],
#        [ 10. ],
#        [ -7.4],
#        [  8.3],
#        [-34.4],
#        [ 28.8],
#        [-15.6],
#        [ -2.5],
#        [ 42.1],
#        [ 25.6],
#        [ -4.3],
#        [  5.2],
#        [  6.2],
#        [  5. ],
#        [-26.5],
#        [-23.5],
#        [  7.5],
#        [  5.8],
#        [-19. ],
#        [-33.2],
#        [ 25.2],
#        [ 33.8],
#        [-10.4],
#        [  3.6],
#        [-32.6],
#        [-39.8],
#        [ 35.7],
#        [ 14.1],
#        [ -9.1],
#        [ -1.6],
#        [  4.5],
#        [ 17.9],
#        [ -0.5],
#        [  0.4],
#        [ 27.3],
#        [-38.4],
#        [ 15.4],
#        [-10.2],
#        [-17. ],
#        [ 20.8],
#        [ 27.1],
#        [ 19.2],
#        [ 22.2],
#        [ -6.7],
#        [ -7.6],
#        [ -3. ],
#        [ 11.6],
#        [  1.3],
#        [  4.6],
#        [-18.8],
#        [ -1.2],
#        [ 13.4],
#        [  9.1],
#        [ -1.7],
#        [ -8.6],
#        [ 23.7],
#        [ -9.6],
#        [-41.6],
#        [-35.1],
#        [ 17.6],
#        [ 10.6],
#        [-42.9],
#        [-31.8],
#        [-26.2],
#        [ -4.6],
#        [ 14. ],
#        [-17.5],
#        [ -5.7],
#        [ -3.6],
#        [ 12.9],
#        [ -8.2],
#        [-39.4],
#        [  1.4],
#        [-11.9],
#        [-18.9],
#        [-24.8],
#        [-35.6],
#        [ 28.2],
#        [ 16.4],
#        [  3.9],
#        [ 10.3],
#        [ -0.6],
#        [  2.4],
#        [-17.8],
#        [-10. ],
#        [ 31.8],
#        [-31. ],
#        [ -7. ],
#        [-25.5],
#        [-13. ],
#        [ 10.8],
#        [ -4.6],
#        [-39.8],
#        [-26.6],
#        [-14.6],
#        [-30.7],
#        [-16.9],
#        [ 35.3],
#        [ 26.3],
#        [ 22.9],
#        [ -4.3],
#        [ 36.6],
#        [ 31.8],
#        [-21.4],
#        [ -4.8],
#        [-36. ],
#        [-24. ],
#        [ -1. ],
#        [ 24.9],
#        [-13.6],
#        [ 17.7],
#        [ -0.2],
#        [  6.8],
#        [-15.3],
#        [ -7.9],
#        [  5. ],
#        [ 25. ],
#        [ 30.1],
#        [ -6.2],
#        [-16.1],
#        [ 29.1],
#        [ -4.6],
#        [-20.2],
#        [-36.1],
#        [ -6.9],
#        [ 23.5],
#        [ -8.7],
#        [ 14.4],
#        [  2.2],
#        [-26.4],
#        [-22.5],
#        [-19.1],
#        [-30.8],
#        [ 16.4],
#        [ 41.1],
#        [ 33. ],
#        [ -8. ],
#        [  9.6],
#        [ 24.3],
#        [  9.1],
#        [  9.2],
#        [-29. ],
#        [  7.6],
#        [ 25.7],
#        [-10.2],
#        [ -2.6],
#        [ 27.8],
#        [  3.4],
#        [ -8.1],
#        [-38.6],
#        [-29.9],
#        [ 14.2],
#        [-19.4],
#        [-17.3],
#        [  0.6],
#        [ -6.7],
#        [-17.9],
#        [-19.4],
#        [  0.3],
#        [ -9.2],
#        [-34.5],
#        [ 16.2],
#        [-14. ],
#        [ 41.9],
#        [-26.8],
#        [ 15.7],
#        [ -4.6],
#        [ 16.9],
#        [-31.1],
#        [ 28.4],
#        [ 40.5],
#        [ -9.3],
#        [ 27.8],
#        [-36.6],
#        [ 39.3],
#        [  4.7],
#        [  5. ],
#        [ 23. ],
#        [ 10.6],
#        [ -0.5],
#        [ -6.7],
#        [ 35.3],
#        [  2.3],
#        [-18.7],
#        [ -3.1],
#        [ 19.6],
#        [ -8.7],
#        [ 17.7],
#        [ 14.3],
#        [ -2.9],
#        [ 12.4],
#        [ -3. ],
#        [ 11.7],
#        [ -5.5],
#        [  8.5],
#        [ -8.1],
#        [ 14. ],
#        [  9.5],
#        [-12.2],
#        [-41.2],
#        [ -9. ],
#        [ -9.4],
#        [-18.9],
#        [ 22.9],
#        [-22.4],
#        [ 20.3],
#        [-17.5],
#        [ 37.2],
#        [ 35.7],
#        [ 10.7],
#        [ 27. ],
#        [  5.5],
#        [ -3.8],
#        [-11.6],
#        [ 32.3],
#        [-27.6],
#        [ 24.5],
#        [ -7.5],
#        [ 30.3],
#        [  2.2],
#        [ 17.4],
#        [  6.3],
#        [ 22.1],
#        [ 10.6],
#        [ 17.9],
#        [-22. ],
#        [-23.3],
#        [ 18.2],
#        [ 27.6],
#        [-11.8],
#        [-32.3],
#        [ 15.8],
#        [ -6.8],
#        [  9. ],
#        [ 29.3],
#        [  9.4],
#        [-12.2],
#        [ 45.1],
#        [ 30.2],
#        [ -8.9],
#        [ 44.6],
#        [  4.8],
#        [ 27.1],
#        [ -4.5],
#        [ -2. ],
#        [ -9.6],
#        [  8.6],
#        [ 36.8],
#        [ -7.2],
#        [-20.4],
#        [ 47.5],
#        [-10.3],
#        [-17. ],
#        [  3.4],
#        [-26.1],
#        [ 23. ],
#        [ -7.2],
#        [ -9.6],
#        [ -6.8],
#        [-27.9],
#        [-26.7],
#        [  1.7],
#        [ -3.6],
#        [-13.9],
#        [-10.8],
#        [ 23.5],
#        [  1.8],
#        [-37.9],
#        [ -4.1],
#        [ -5.1],
#        [  5.2],
#        [-41.5],
#        [ -0.4],
#        [ 15.2],
#        [ 23.7],
#        [ 18.8],
#        [-12.6],
#        [ 16.2],
#        [  8.7],
#        [ -3.5],
#        [  1.5],
#        [  0.2],
#        [ 23.3],
#        [-15.8],
#        [ -3.7],
#        [ -7.9],
#        [-15. ],
#        [ -4.6],
#        [ -8.7],
#        [ 27.6],
#        [ 27.5],
#        [ 13. ],
#        [ 27.8],
#        [ -1.5],
#        [ 16.4],
#        [ -5.8],
#        [-18.6],
#        [ 28.5],
#        [ -1.1],
#        [  7.9],
#        [-22.9],
#        [  7.3],
#        [ 11.6],
#        [  8.3],
#        [ -7.4],
#        [ 22. ],
#        [ -3.4],
#        [  0.5],
#        [-17.9],
#        [ -2.8],
#        [  2.6],
#        [-10.8],
#        [  3.5],
#        [  7.8],
#        [ -2.2],
#        [ -4.5],
#        [ -4.3],
#        [  1.3],
#        [ 11.7],
#        [ 25.9],
#        [  0.2],
#        [-12.8],
#        [  8.9],
#        [  9.5],
#        [-31.5],
#        [ -7.9],
#        [-22.9],
#        [  2.7],
#        [  3.3],
#        [ 32.9],
#        [  7.9],
#        [ -2.6],
#        [-31.5],
#        [  5.4],
#        [-19.8],
#        [ -7.5],
#        [ -8.3],
#        [ 20.4],
#        [  5.6],
#        [ 20.7],
#        [ -3.5]])

# %%
#plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])), np.squeeze(training_data['targets']))
